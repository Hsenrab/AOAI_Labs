# %% [markdown]
# # Process Documents
#
# This document shows you how to load a pdf from azure blob storage, gain some anaysis and insight with AI and save results to a cosmosdb.
#
#
# - ## Overview
# - Step 1 Connect to Blob
# - Step 2 Connect to AI Foundry
# - Step 3 Connect to Cosmos
# - Step 4 load in pdf and extract text.
# - Step 5 chunk data (simple page split)
# - Step 6 extract insight from chunk
# - Step 7 combine insights
# - Step 8 Save insights to cosmos
# - Step 9 Query Cosmos for results
